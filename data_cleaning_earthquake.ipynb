# %%
# Dependencies
import pandas as pd
import csv, os

# %%
# File paths
data_path_1 = "Resources/earthquake_database.csv"
data_path_2 = "Resources/Worldwide-Earthquake-database.csv"

# %%
# Read CSV
earthquake_data = pd.read_csv(data_path_1)
worldwide_earthquake_database = pd.read_csv(data_path_2)

# %%
earthquake_data.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %%
# Changing the Date to datetime format
earthquake_data["Date"] = pd.to_datetime(earthquake_data["Date"], utc = True)
earthquake_data.head()
# Out:
#                        Date      Time  Latitude  Longitude        Type  Depth  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  Earthquake  131.6
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352  Earthquake   80.0
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427  Earthquake   15.0
#
#    Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0          NaN                     NaN        6.0             MW  ...
# 1          NaN                     NaN        5.8             MW  ...
# 2          NaN                     NaN        6.2             MW  ...
# 3          NaN                     NaN        5.8             MW  ...
# 4          NaN                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %%
# Extract the year from the datetime column
earthquake_data["Year"] = pd.DatetimeIndex(earthquake_data["Date"]).year
earthquake_data.head()
# Out:
#                        Date      Time  Latitude  Longitude        Type  Depth  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  Earthquake  131.6
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352  Earthquake   80.0
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427  Earthquake   15.0
#
#    Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0          NaN                     NaN        6.0             MW  ...
# 1          NaN                     NaN        5.8             MW  ...
# 2          NaN                     NaN        6.2             MW  ...
# 3          NaN                     NaN        5.8             MW  ...
# 4          NaN                     NaN        5.8             MW  ...
#
#    Azimuthal Gap  Horizontal Distance  Horizontal Error  Root Mean Square  \
# 0            NaN                  NaN               NaN               NaN
# 1            NaN                  NaN               NaN               NaN
# 2            NaN                  NaN               NaN               NaN
# 3            NaN                  NaN               NaN               NaN
# 4            NaN                  NaN               NaN               NaN
#
#              ID  Source Location Source Magnitude Source     Status  Year
# 0  ISCGEM860706  ISCGEM          ISCGEM           ISCGEM  Automatic  1965
# 1  ISCGEM860737  ISCGEM          ISCGEM           ISCGEM  Automatic  1965
# 2  ISCGEM860762  ISCGEM          ISCGEM           ISCGEM  Automatic  1965
# 3  ISCGEM860856  ISCGEM          ISCGEM           ISCGEM  Automatic  1965
# 4  ISCGEM860890  ISCGEM          ISCGEM           ISCGEM  Automatic  1965
#
# [5 rows x 22 columns]

# %%
# Drop unwanted columns
cleaned_earthquake_df = earthquake_data.loc[:, ["Year",
                                                "Latitude",
                                                "Longitude",
                                                "Magnitude"]]

# %%
# Filter the dataset to only 2015 or later and reset index and save to new CSV file
cleaned_earthquake_df = cleaned_earthquake_df.loc[(cleaned_earthquake_df)["Year"] >= 2015]
cleaned_earthquake_df.reset_index(drop = True, inplace = True)
cleaned_earthquake_df.to_csv("Resources/cleaned_earthquake_database.CSV")
cleaned_earthquake_df
# Out:
#      Year  Latitude  Longitude  Magnitude
# 0    2015    6.5739    60.3653        5.5
# 1    2015  -43.0546   171.2364        5.6
# 2    2015   55.2049   163.2446        5.6
# 3    2015    5.9045   -82.6576        6.5
# 4    2015  -61.6118   161.3346        5.7
# ..    ...       ...        ...        ...
# 910  2016   38.3917  -118.8941        5.6
# 911  2016   38.3777  -118.8957        5.5
# 912  2016   36.9179   140.4262        5.9
# 913  2016   -9.0283   118.6639        6.3
# 914  2016   37.3973   141.4103        5.5
#
# [915 rows x 4 columns]

# %%
worldwide_earthquake_database.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH  DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0     1           No -2150    NaN  NaN   NaN     NaN                 NaN
# 1     2          Yes -2000    NaN  NaN   NaN     NaN    NaN          NaN
# 2     3           No -2000    NaN  NaN   NaN     NaN    NaN         18.0
# 3  5877          Yes -1610    NaN  NaN   NaN     NaN    NaN          NaN
# 4     8           No -1566    NaN  NaN   NaN     NaN                 NaN
#
#    EQ_PRIMARY  ...  TOTAL_MISSING  TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  \
# 0         7.3  ...            NaN                        NaN             NaN
# 1         NaN  ...            NaN                        NaN             NaN
# 2         7.1  ...            NaN                        NaN             NaN
# 3         NaN  ...            NaN                        NaN             NaN
# 4         NaN  ...            NaN                        NaN             NaN
#
#    TOTAL_INJURIES_DESCRIPTION  TOTAL_DAMAGE_MILLIONS_DOLLARS  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#    TOTAL_DAMAGE_DESCRIPTION  TOTAL_HOUSES_DESTROYED  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       1.0                     NaN
# 3                       3.0                     NaN
# 4                       NaN                     NaN
#
#   TOTAL_HOUSES_DESTROYED_DESCRIPTION TOTAL_HOUSES_DAMAGED  \
# 0                                NaN                  NaN
# 1                                NaN                  NaN
# 2                                1.0                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
#
#   TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 47 columns]

# %%
# Drop unwanted columns
cleaned_worldwide_earthquake_df = worldwide_earthquake_database.loc[:, ["YEAR",
                                                                        "EQ_PRIMARY",
                                                                        "EQ_MAG_MW",
                                                                        "EQ_MAG_MS",
                                                                        "EQ_MAG_MB",
                                                                        "EQ_MAG_ML",
                                                                        "EQ_MAG_MFA",
                                                                        "EQ_MAG_UNK",
                                                                        "INTENSITY",
                                                                        "COUNTRY",
                                                                        "LATITUDE",
                                                                        "LONGITUDE",
                                                                        "TOTAL_DEATHS",
                                                                        "INJURIES",
                                                                        "TOTAL_DAMAGE_MILLIONS_DOLLARS"]]

cleaned_worldwide_earthquake_df.head()
# Out:
#    YEAR  EQ_PRIMARY  EQ_PRIMARY  EQ_MAG_MW  EQ_MAG_MS  EQ_MAG_MB  EQ_MAG_ML  \
# 0 -2150         7.3         7.3        NaN        NaN        NaN        NaN
# 1 -2000         NaN         NaN        NaN        NaN        NaN        NaN
# 2 -2000         7.1         7.1        NaN        7.1        NaN        NaN
# 3 -1610         NaN         NaN        NaN        NaN        NaN        NaN
# 4 -1566         NaN         NaN        NaN        NaN        NaN        NaN
#
#    EQ_MAG_MFA  EQ_MAG_UNK  INTENSITY       COUNTRY LATITUDE LONGITUDE  \
# 0         NaN         7.3        NaN        JORDAN     31.1      35.5
# 1         NaN         NaN       10.0         SYRIA   35.683      35.8
# 2         NaN         NaN       10.0  TURKMENISTAN       38      58.2
# 3         NaN         NaN        NaN        GREECE     36.4      25.4
# 4         NaN         NaN       10.0        ISRAEL     31.5      35.3
#
#    TOTAL_DEATHS  INJURIES  TOTAL_DAMAGE_MILLIONS_DOLLARS
# 0           NaN       NaN                            NaN
# 1           NaN       NaN                            NaN
# 2           1.0       NaN                            NaN
# 3           NaN       NaN                            NaN
# 4           NaN       NaN                            NaN

# %%
# Filter the dataset to only 2015 or later and reset index and save to new CSV file
cleaned_worldwide_earthquake_df = cleaned_worldwide_earthquake_df.loc[(cleaned_worldwide_earthquake_df)["YEAR"] >= 2015]
cleaned_worldwide_earthquake_df.reset_index(drop = True, inplace = True)
cleaned_worldwide_earthquake_df.to_csv("Resources/cleaned_worldwide_earthquake_data.CSV")
cleaned_worldwide_earthquake_df
# Out:
#      YEAR  EQ_PRIMARY  EQ_PRIMARY  EQ_MAG_MW  EQ_MAG_MS  EQ_MAG_MB  EQ_MAG_ML  \
# 0    2015         5.3         5.3        NaN        NaN        5.3        NaN
# 1    2015         6.7         6.7        6.7        NaN        NaN        NaN
# 2    2015         6.4         6.4        6.4        NaN        NaN        NaN
# 3    2015         4.5         4.5        NaN        NaN        4.5        NaN
# 4    2015         3.6         3.6        NaN        NaN        NaN        3.6
# ..    ...         ...         ...        ...        ...        ...        ...
# 299  2020         5.3         5.3        5.3        NaN        NaN        NaN
# 300  2020         6.6         6.6        6.6        NaN        NaN        NaN
# 301  2020         4.6         4.6        NaN        NaN        4.6        NaN
# 302  2020         5.2         5.2        5.2        NaN        NaN        NaN
# 303  2020         NaN         NaN        NaN        NaN        NaN        NaN
#
#      EQ_MAG_MFA  EQ_MAG_UNK  INTENSITY             COUNTRY LATITUDE LONGITUDE  \
# 0           NaN         NaN        6.0               CHINA   29.353   103.199
# 1           NaN         NaN        4.0               JAPAN   39.856   142.881
# 2           NaN         NaN        5.0             VANUATU  -16.431   168.148
# 3           NaN         NaN        NaN               CHINA    23.01   101.755
# 4           NaN         NaN        NaN  BOSNIA-HERZEGOVINA   44.534    18.934
# ..          ...         ...        ...                 ...      ...       ...
# 299         NaN         NaN        NaN               CHINA   33.124    98.916
# 300         NaN         NaN        7.0              GREECE   34.205    25.712
# 301         NaN         NaN        NaN                IRAN   35.725    52.044
# 302         NaN         NaN        NaN               CHINA   27.296   103.281
# 303         NaN         NaN        NaN           INDONESIA   -8.058   114.242
#
#      TOTAL_DEATHS  INJURIES  TOTAL_DAMAGE_MILLIONS_DOLLARS
# 0             NaN      11.0                            NaN
# 1             NaN       NaN                            NaN
# 2             NaN       NaN                            NaN
# 3             NaN       NaN                            NaN
# 4             4.0       1.0                            NaN
# ..            ...       ...                            ...
# 299           NaN       NaN                          11.28
# 300           NaN       NaN                            NaN
# 301           2.0      22.0                            NaN
# 302           4.0      24.0                            NaN
# 303           1.0       NaN                            NaN
#
# [304 rows x 16 columns]
