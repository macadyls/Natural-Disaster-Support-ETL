# %%
# Dependencies
import pandas as pd
import csv, os

# %%
# File paths
data_path_1 = "Resources/WH_2015.csv"
data_path_2 = "Resources/WH_2016.csv"
data_path_3 = "Resources/WH_2017.csv"
data_path_4 = "Resources/WH_2018.csv"
data_path_5 = "Resources/WH_2019.csv"

# %%
# Read CSV
wh_2015_db = pd.read_csv(data_path_1)
wh_2016_db = pd.read_csv(data_path_2)
wh_2017_db = pd.read_csv(data_path_3)
wh_2018_db = pd.read_csv(data_path_4)
wh_2019_db = pd.read_csv(data_path_5)

# %%
# Drop unwanted columns and merge
wh_2015_v1 = wh_2015_db.loc[:, ["Country",
                                "Happiness Rank",
                                "Happiness Score"]]

wh_2016_v1 = wh_2016_db.loc[:, ["Country",
                                "Happiness Rank",
                                "Happiness Score"]]

combined_df =  pd.merge(wh_2015_v1,wh_2016_v1, on = ["Country"], how = "outer")

# %%
# Rename columns
combined_df = combined_df.rename(columns = {"Happiness Rank_x": "Rank 2015",
                                            "Happiness Score_x": "Score 2015",
                                            "Happiness Rank_y": "Rank 2016",
                                            "Happiness Score_y":"Score 2016"})

combined_df.head()
# Out:
#        Country  Rank 2015  Score 2015  Rank 2016  Score 2016
# 0  Switzerland        1.0       7.587        2.0       7.509
# 1      Iceland        2.0       7.561        3.0       7.501
# 2      Denmark        3.0       7.527        1.0       7.526
# 3       Norway        4.0       7.522        4.0       7.498
# 4       Canada        5.0       7.427        6.0       7.404

# %%
# Drop unwanted columns and merge
wh_2017_v1 = wh_2017_db.loc[:, ["Country",
                                "Happiness.Rank",
                                "Happiness.Score"]]

combined_df =  pd.merge(combined_df,wh_2017_v1, on = ["Country"], how = "outer")
combined_df
# Out:
#                       Country  Rank 2015  Score 2015  Rank 2016  Score 2016  \
# 0                 Switzerland        1.0       7.587        2.0       7.509
# 1                     Iceland        2.0       7.561        3.0       7.501
# 2                     Denmark        3.0       7.527        1.0       7.526
# 3                      Norway        4.0       7.522        4.0       7.498
# 4                      Canada        5.0       7.427        6.0       7.404
# ..                        ...        ...         ...        ...         ...
# 161         Somaliland Region        NaN         NaN       97.0       5.057
# 162                   Namibia        NaN         NaN      113.0       4.574
# 163               South Sudan        NaN         NaN      143.0       3.832
# 164  Taiwan Province of China        NaN         NaN        NaN         NaN
# 165   Hong Kong S.A.R., China        NaN         NaN        NaN         NaN
#
#      Happiness.Rank  Happiness.Score
# 0               4.0            7.494
# 1               3.0            7.504
# 2               2.0            7.522
# 3               1.0            7.537
# 4               7.0            7.316
# ..              ...              ...
# 161             NaN              NaN
# 162           111.0            4.574
# 163           147.0            3.591
# 164            33.0            6.422
# 165            71.0            5.472
#
# [166 rows x 7 columns]

# %%
# Rename columns
combined_df = combined_df.rename(columns = {"Happiness.Rank": "Rank 2017",
                                            "Happiness.Score": "Score 2017"})

combined_df.head()
# Out:
#        Country  Rank 2015  Score 2015  Rank 2016  Score 2016  Rank 2017  \
# 0  Switzerland        1.0       7.587        2.0       7.509        4.0
# 1      Iceland        2.0       7.561        3.0       7.501        3.0
# 2      Denmark        3.0       7.527        1.0       7.526        2.0
# 3       Norway        4.0       7.522        4.0       7.498        1.0
# 4       Canada        5.0       7.427        6.0       7.404        7.0
#
#    Score 2017
# 0       7.494
# 1       7.504
# 2       7.522
# 3       7.537
# 4       7.316

# %%
# Drop unwanted columns, rename and merge
wh_2018_v1 = wh_2018_db.loc[:, ["Country or region",
                                "Overall rank",
                                "Score"]]

wh_2018_v1 = wh_2018_v1.rename(columns = {"Country or region": "Country",
                                          "Overall rank": "Rank 2018",
                                          "Score": "Score 2018"})

combined_df =  pd.merge(combined_df,wh_2018_v1, on = ["Country"], how = "outer")

# %%
# Drop unwanted columns, rename and merge
wh_2019_v1 = wh_2019_db.loc[:, ["Country or region",
                                "Overall rank",
                                "Score"]]

wh_2019_v1 = wh_2019_v1.rename(columns = {"Country or region": "Country",
                                          "Overall rank": "Rank 2019",
                                          "Score": "Score 2019"})

combined_df =  pd.merge(combined_df,wh_2019_v1, on = ["Country"], how = "outer")
combined_df
# Out:
#                      Country  Rank 2015  Score 2015  Rank 2016  Score 2016  \
# 0                Switzerland        1.0       7.587        2.0       7.509
# 1                    Iceland        2.0       7.561        3.0       7.501
# 2                    Denmark        3.0       7.527        1.0       7.526
# 3                     Norway        4.0       7.522        4.0       7.498
# 4                     Canada        5.0       7.427        6.0       7.404
# ..                       ...        ...         ...        ...         ...
# 165  Hong Kong S.A.R., China        NaN         NaN        NaN         NaN
# 166        Trinidad & Tobago        NaN         NaN        NaN         NaN
# 167          Northern Cyprus        NaN         NaN        NaN         NaN
# 168          North Macedonia        NaN         NaN        NaN         NaN
# 169                   Gambia        NaN         NaN        NaN         NaN
#
#      Rank 2017  Score 2017  Rank 2018  Score 2018  Rank 2019  Score 2019
# 0          4.0       7.494        5.0       7.487        6.0       7.480
# 1          3.0       7.504        4.0       7.495        4.0       7.494
# 2          2.0       7.522        3.0       7.555        2.0       7.600
# 3          1.0       7.537        2.0       7.594        3.0       7.554
# 4          7.0       7.316        7.0       7.328        9.0       7.278
# ..         ...         ...        ...         ...        ...         ...
# 165       71.0       5.472        NaN         NaN        NaN         NaN
# 166        NaN         NaN       38.0       6.192       39.0       6.192
# 167        NaN         NaN       58.0       5.835       64.0       5.718
# 168        NaN         NaN        NaN         NaN       84.0       5.274
# 169        NaN         NaN        NaN         NaN      120.0       4.516
#
# [170 rows x 11 columns]

# %%
# Convert Country column name 
combined_df = combined_df.rename(columns = {"Country" : "Country_Name"})
combined_df
# Out:
#                 Country_Name  Rank 2015  Score 2015  Rank 2016  Score 2016  \
# 0                Switzerland        1.0       7.587        2.0       7.509
# 1                    Iceland        2.0       7.561        3.0       7.501
# 2                    Denmark        3.0       7.527        1.0       7.526
# 3                     Norway        4.0       7.522        4.0       7.498
# 4                     Canada        5.0       7.427        6.0       7.404
# ..                       ...        ...         ...        ...         ...
# 165  Hong Kong S.A.R., China        NaN         NaN        NaN         NaN
# 166        Trinidad & Tobago        NaN         NaN        NaN         NaN
# 167          Northern Cyprus        NaN         NaN        NaN         NaN
# 168          North Macedonia        NaN         NaN        NaN         NaN
# 169                   Gambia        NaN         NaN        NaN         NaN
#
#      Rank 2017  Score 2017  Rank 2018  Score 2018  Rank 2019  Score 2019
# 0          4.0       7.494        5.0       7.487        6.0       7.480
# 1          3.0       7.504        4.0       7.495        4.0       7.494
# 2          2.0       7.522        3.0       7.555        2.0       7.600
# 3          1.0       7.537        2.0       7.594        3.0       7.554
# 4          7.0       7.316        7.0       7.328        9.0       7.278
# ..         ...         ...        ...         ...        ...         ...
# 165       71.0       5.472        NaN         NaN        NaN         NaN
# 166        NaN         NaN       38.0       6.192       39.0       6.192
# 167        NaN         NaN       58.0       5.835       64.0       5.718
# 168        NaN         NaN        NaN         NaN       84.0       5.274
# 169        NaN         NaN        NaN         NaN      120.0       4.516
#
# [170 rows x 11 columns]

# %%
# Save to CSV
combined_df.to_csv("Resources/cleaned_WH_data.CSV", index = False)

# %%
country_df = pd.DataFrame(combined_df["Country_Name"])
country_df
# Out:
#                 Country_Name
# 0                Switzerland
# 1                    Iceland
# 2                    Denmark
# 3                     Norway
# 4                     Canada
# ..                       ...
# 165  Hong Kong S.A.R., China
# 166        Trinidad & Tobago
# 167          Northern Cyprus
# 168          North Macedonia
# 169                   Gambia
#
# [170 rows x 1 columns]

# %%
volcano_path = "Resources/cleaned_volcano_data.CSV"
volcano_df= pd.read_csv(volcano_path)
volcano_df
# Out:
#     Year              Country_Name  Elevation  Total_Deaths  \
# 0   2010                   Ecuador       5023           NaN
# 1   2010                   Iceland       1666           2.0
# 2   2010                 Guatemala       2552           1.0
# 3   2010  United States of America        538           NaN
# 4   2010                 Indonesia       1784           4.0
# ..   ...                       ...        ...           ...
# 58  2018  United States of America       1222           1.0
# 59  2018          Papua New Guinea        365           NaN
# 60  2018                 Indonesia       2799           NaN
# 61  2018  United States of America       1222           NaN
# 62  2018                   Vanuatu       1496           4.0
#
#     Total_Missing_Persons  Total_Injuries
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     3.0             NaN
# 3                     NaN             NaN
# 4                     NaN             5.0
# ..                    ...             ...
# 58                    NaN             3.0
# 59                    NaN             NaN
# 60                    NaN            30.0
# 61                    NaN             NaN
# 62                    NaN             NaN
#
# [63 rows x 6 columns]

# %%
# Test for country column consistency
merged_df = country_df.merge(volcano_df, on="Country_Name", how="outer", indicator=True)
merged_df
# Out:
#          Country_Name    Year  Elevation  Total_Deaths  Total_Missing_Persons  \
# 0         Switzerland     NaN        NaN           NaN                    NaN
# 1             Iceland  2010.0     1666.0           2.0                    NaN
# 2             Iceland  2011.0     1512.0           NaN                    NaN
# 3             Denmark     NaN        NaN           NaN                    NaN
# 4              Norway     NaN        NaN           NaN                    NaN
# ..                ...     ...        ...           ...                    ...
# 218  Papua New Guinea  2015.0     1807.0           NaN                    NaN
# 219  Papua New Guinea  2018.0      365.0           NaN                    NaN
# 220  Papua New Guinea  2018.0      365.0           NaN                    NaN
# 221           Vanuatu  2017.0     1496.0           NaN                    NaN
# 222           Vanuatu  2018.0     1496.0           4.0                    NaN
#
#      Total_Injuries      _merge
# 0               NaN   left_only
# 1               NaN        both
# 2               NaN        both
# 3               NaN   left_only
# 4               NaN   left_only
# ..              ...         ...
# 218             2.0  right_only
# 219             NaN  right_only
# 220             NaN  right_only
# 221             NaN  right_only
# 222             NaN  right_only
#
# [223 rows x 7 columns]

# %%
merged_df[merged_df["_merge"] == "right_only"]
# Out:
#                  Country_Name    Year  Elevation  Total_Deaths  \
# 208  United States of America  2010.0      538.0           NaN
# 209  United States of America  2012.0     1222.0           NaN
# 210  United States of America  2012.0     1222.0           NaN
# 211  United States of America  2014.0     1222.0           NaN
# 212  United States of America  2016.0     2805.0           1.0
# 213  United States of America  2018.0     1222.0           1.0
# 214  United States of America  2018.0     1222.0           NaN
# 215                   Eritrea  2011.0     2218.0          31.0
# 216        Russian Federation  2012.0     3682.0           NaN
# 217                Cabo Verde  2014.0     2829.0           NaN
# 218          Papua New Guinea  2015.0     1807.0           NaN
# 219          Papua New Guinea  2018.0      365.0           NaN
# 220          Papua New Guinea  2018.0      365.0           NaN
# 221                   Vanuatu  2017.0     1496.0           NaN
# 222                   Vanuatu  2018.0     1496.0           4.0
#
#      Total_Missing_Persons  Total_Injuries      _merge
# 208                    NaN             NaN  right_only
# 209                    NaN             NaN  right_only
# 210                    NaN             NaN  right_only
# 211                    NaN             NaN  right_only
# 212                    NaN             NaN  right_only
# 213                    NaN             3.0  right_only
# 214                    NaN             NaN  right_only
# 215                    NaN             NaN  right_only
# 216                    NaN             NaN  right_only
# 217                    NaN             NaN  right_only
# 218                    NaN             2.0  right_only
# 219                    NaN             NaN  right_only
# 220                    NaN             NaN  right_only
# 221                    NaN             NaN  right_only
# 222                    NaN             NaN  right_only

# %%
country_path = "Resources/UNSD — Methodology.CSV"
country_df = pd.read_csv(country_path, error_bad_lines=False)
country_df
# Out:
# b'Skipping line 67: expected 16 fields, saw 17\nSkipping line 126: expected 16 fields, saw 17\nSkipping line 127: expected 16 fields, saw 17\n'
#      Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0              1       World          2.0      Africa             15.0
# 1              1       World          2.0      Africa             15.0
# 2              1       World          2.0      Africa             15.0
# 3              1       World          2.0      Africa             15.0
# 4              1       World          2.0      Africa             15.0
# ..           ...         ...          ...         ...              ...
# 241            1       World          9.0     Oceania             61.0
# 242            1       World          9.0     Oceania             61.0
# 243            1       World          9.0     Oceania             61.0
# 244            1       World          9.0     Oceania             61.0
# 245            1       World          9.0     Oceania             61.0
#
#      Sub-region Name  Intermediate Region Code Intermediate Region Name  \
# 0    Northern Africa                       NaN                      NaN
# 1    Northern Africa                       NaN                      NaN
# 2    Northern Africa                       NaN                      NaN
# 3    Northern Africa                       NaN                      NaN
# 4    Northern Africa                       NaN                      NaN
# ..               ...                       ...                      ...
# 241        Polynesia                       NaN                      NaN
# 242        Polynesia                       NaN                      NaN
# 243        Polynesia                       NaN                      NaN
# 244        Polynesia                       NaN                      NaN
# 245        Polynesia                       NaN                      NaN
#
#                Country or Area  M49 Code ISO-alpha2 Code ISO-alpha3 Code  \
# 0                      Algeria        12              DZ             DZA
# 1                        Egypt       818              EG             EGY
# 2                        Libya       434              LY             LBY
# 3                      Morocco       504              MA             MAR
# 4                        Sudan       729              SD             SDN
# ..                         ...       ...             ...             ...
# 241                      Samoa       882              WS             WSM
# 242                    Tokelau       772              TK             TKL
# 243                      Tonga       776              TO             TON
# 244                     Tuvalu       798              TV             TUV
# 245  Wallis and Futuna Islands       876              WF             WLF
#
#     Least Developed Countries (LDC) Land Locked Developing Countries (LLDC)  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                                 x                                     NaN
# ..                              ...                                     ...
# 241                             NaN                                     NaN
# 242                             NaN                                     NaN
# 243                             NaN                                     NaN
# 244                               x                                     NaN
# 245                             NaN                                     NaN
#
#     Small Island Developing States (SIDS) Developed / Developing Countries
# 0                                     NaN                       Developing
# 1                                     NaN                       Developing
# 2                                     NaN                       Developing
# 3                                     NaN                       Developing
# 4                                     NaN                       Developing
# ..                                    ...                              ...
# 241                                     x                       Developing
# 242                                   NaN                       Developing
# 243                                     x                       Developing
# 244                                     x                       Developing
# 245                                   NaN                       Developing
#
# [246 rows x 16 columns]

# %%
# Dropping unwanted columns
cleaned_country_df = pd.DataFrame(country_df, columns = {"Country or Area", "M49 Code", "ISO-alpha3 Code", "Developed / Developing Countries"})
cleaned_country_df
# Out:
#     ISO-alpha3 Code            Country or Area  M49 Code  \
# 0               DZA                    Algeria        12
# 1               EGY                      Egypt       818
# 2               LBY                      Libya       434
# 3               MAR                    Morocco       504
# 4               SDN                      Sudan       729
# ..              ...                        ...       ...
# 241             WSM                      Samoa       882
# 242             TKL                    Tokelau       772
# 243             TON                      Tonga       776
# 244             TUV                     Tuvalu       798
# 245             WLF  Wallis and Futuna Islands       876
#
#     Developed / Developing Countries
# 0                         Developing
# 1                         Developing
# 2                         Developing
# 3                         Developing
# 4                         Developing
# ..                               ...
# 241                       Developing
# 242                       Developing
# 243                       Developing
# 244                       Developing
# 245                       Developing
#
# [246 rows x 4 columns]

# %%
# Checking for duplicates
cleaned_country_df.drop_duplicates(subset=['Country or Area'])
cleaned_country_df
# Out:
#     ISO-alpha3 Code            Country or Area  M49 Code  \
# 0               DZA                    Algeria        12
# 1               EGY                      Egypt       818
# 2               LBY                      Libya       434
# 3               MAR                    Morocco       504
# 4               SDN                      Sudan       729
# ..              ...                        ...       ...
# 241             WSM                      Samoa       882
# 242             TKL                    Tokelau       772
# 243             TON                      Tonga       776
# 244             TUV                     Tuvalu       798
# 245             WLF  Wallis and Futuna Islands       876
#
#     Developed / Developing Countries
# 0                         Developing
# 1                         Developing
# 2                         Developing
# 3                         Developing
# 4                         Developing
# ..                               ...
# 241                       Developing
# 242                       Developing
# 243                       Developing
# 244                       Developing
# 245                       Developing
#
# [246 rows x 4 columns]

# %%
cleaned_country_df = cleaned_country_df.rename(columns = {"Country or Area": "Country_Name",
                                                          "M49 Code":"Country_ID",
                                                          "ISO-alpha3 Code": "Country_Abbreviation",
                                                         "Developed / Developing Countries": "Developed_Or_Developing"})
cleaned_country_df
# Out:
#     Country_Abbreviation               Country_Name  Country_ID  \
# 0                    DZA                    Algeria          12
# 1                    EGY                      Egypt         818
# 2                    LBY                      Libya         434
# 3                    MAR                    Morocco         504
# 4                    SDN                      Sudan         729
# ..                   ...                        ...         ...
# 241                  WSM                      Samoa         882
# 242                  TKL                    Tokelau         772
# 243                  TON                      Tonga         776
# 244                  TUV                     Tuvalu         798
# 245                  WLF  Wallis and Futuna Islands         876
#
#     Developed_Or_Developing
# 0                Developing
# 1                Developing
# 2                Developing
# 3                Developing
# 4                Developing
# ..                      ...
# 241              Developing
# 242              Developing
# 243              Developing
# 244              Developing
# 245              Developing
#
# [246 rows x 4 columns]

# %%
# Save to CSV
cleaned_country_df.to_csv("Resources/cleaned_country_data.CSV", index = False)

# %%
# Test for country column consistency
merged_df = cleaned_country_df.merge(volcano_df, on="Country_Name", how="outer", indicator=True)
merged_df
# Out:
#     Country_Abbreviation               Country_Name  Country_ID  \
# 0                    DZA                    Algeria          12
# 1                    EGY                      Egypt         818
# 2                    LBY                      Libya         434
# 3                    MAR                    Morocco         504
# 4                    SDN                      Sudan         729
# ..                   ...                        ...         ...
# 288                  WSM                      Samoa         882
# 289                  TKL                    Tokelau         772
# 290                  TON                      Tonga         776
# 291                  TUV                     Tuvalu         798
# 292                  WLF  Wallis and Futuna Islands         876
#
#     Developed_Or_Developing  Year  Elevation  Total_Deaths  \
# 0                Developing   NaN        NaN           NaN
# 1                Developing   NaN        NaN           NaN
# 2                Developing   NaN        NaN           NaN
# 3                Developing   NaN        NaN           NaN
# 4                Developing   NaN        NaN           NaN
# ..                      ...   ...        ...           ...
# 288              Developing   NaN        NaN           NaN
# 289              Developing   NaN        NaN           NaN
# 290              Developing   NaN        NaN           NaN
# 291              Developing   NaN        NaN           NaN
# 292              Developing   NaN        NaN           NaN
#
#      Total_Missing_Persons  Total_Injuries     _merge
# 0                      NaN             NaN  left_only
# 1                      NaN             NaN  left_only
# 2                      NaN             NaN  left_only
# 3                      NaN             NaN  left_only
# 4                      NaN             NaN  left_only
# ..                     ...             ...        ...
# 288                    NaN             NaN  left_only
# 289                    NaN             NaN  left_only
# 290                    NaN             NaN  left_only
# 291                    NaN             NaN  left_only
# 292                    NaN             NaN  left_only
#
# [293 rows x 10 columns]

# %%
merged_df[merged_df["_merge"] == "right_only"]
# Out:
# Empty DataFrame
# Columns: [Country_Abbreviation, Country_Name, Country_ID, Developed_Or_Developing, Year, Elevation, Total_Deaths, Total_Missing_Persons, Total_Injuries, _merge]
# Index: []

# %%
earthquake_path = "Resources/cleaned_worldwide_earthquake_data.CSV"
earthquake_df= pd.read_csv(earthquake_path)
earthquake_df
# Out:
#      Year  Magnitude     Country_Name  Total_Deaths  Total_Missing_Persons  \
# 0    2010        NaN       Tajikistan           NaN                    NaN
# 1    2010        6.6  Solomon Islands           NaN                    NaN
# 2    2010        7.1  Solomon Islands           NaN                    NaN
# 3    2010        6.8  Solomon Islands           NaN                    NaN
# 4    2010        NaN        Indonesia           1.0                    NaN
# ..    ...        ...              ...           ...                    ...
# 502  2018        7.5    New Caledonia           NaN                    NaN
# 503  2018        5.6          Vanuatu           NaN                    NaN
# 504  2018        5.4            China           NaN                    NaN
# 505  2018        5.5       Mozambique           NaN                    NaN
# 506  2018        NaN            Italy           NaN                    NaN
#
#      Total_Injuries
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               2.0
# ..              ...
# 502             NaN
# 503             NaN
# 504            17.0
# 505            10.0
# 506            28.0
#
# [507 rows x 6 columns]

# %%
merged_df2 = cleaned_country_df.merge(earthquake_df, on="Country_Name", how="outer", indicator=True)
merged_df2
# Out:
#     Country_Abbreviation               Country_Name  Country_ID  \
# 0                    DZA                    Algeria          12
# 1                    DZA                    Algeria          12
# 2                    DZA                    Algeria          12
# 3                    DZA                    Algeria          12
# 4                    DZA                    Algeria          12
# ..                   ...                        ...         ...
# 680                  WSM                      Samoa         882
# 681                  TKL                    Tokelau         772
# 682                  TON                      Tonga         776
# 683                  TUV                     Tuvalu         798
# 684                  WLF  Wallis and Futuna Islands         876
#
#     Developed_Or_Developing    Year  Magnitude  Total_Deaths  \
# 0                Developing  2010.0        NaN           2.0
# 1                Developing  2013.0        NaN           NaN
# 2                Developing  2013.0        NaN           NaN
# 3                Developing  2014.0        5.5           6.0
# 4                Developing  2014.0        NaN           NaN
# ..                      ...     ...        ...           ...
# 680              Developing     NaN        NaN           NaN
# 681              Developing     NaN        NaN           NaN
# 682              Developing     NaN        NaN           NaN
# 683              Developing     NaN        NaN           NaN
# 684              Developing     NaN        NaN           NaN
#
#      Total_Missing_Persons  Total_Injuries     _merge
# 0                      NaN            43.0       both
# 1                      NaN             5.0       both
# 2                      NaN            11.0       both
# 3                      NaN           420.0       both
# 4                      NaN             NaN       both
# ..                     ...             ...        ...
# 680                    NaN             NaN  left_only
# 681                    NaN             NaN  left_only
# 682                    NaN             NaN  left_only
# 683                    NaN             NaN  left_only
# 684                    NaN             NaN  left_only
#
# [685 rows x 10 columns]

# %%
merged_df2[merged_df2["_merge"] == "right_only"]
# Out:
# Empty DataFrame
# Columns: [Country_Abbreviation, Country_Name, Country_ID, Developed_Or_Developing, Year, Magnitude, Total_Deaths, Total_Missing_Persons, Total_Injuries, _merge]
# Index: []

# %%
tsunami_path = "Resources/cleaned_tsunami_data.CSV"
tsunami_df= pd.read_csv(tsunami_path)
tsunami_df
# Out:
#      Year        Country_Name                     Cause  \
# 0    2010     Solomon Islands                Earthquake
# 1    2010     Solomon Islands                Earthquake
# 2    2010     Solomon Islands                Earthquake
# 3    2010               Haiti  Earthquake and Landslide
# 4    2010               Chile                Earthquake
# ..    ...                 ...                       ...
# 133  2018       New Caledonia                Earthquake
# 134  2018  Russian Federation                 Landslide
# 135  2014             Iceland                 Landslide
# 136  2016               Japan                Earthquake
# 137  2013              Mexico                Earthquake
#
#                          Total_Deaths
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3    Very Many (~1001 or more people)
# 4          Many (~101 to 1000 people)
# ..                                ...
# 133                               NaN
# 134                               NaN
# 135                               NaN
# 136                               NaN
# 137                               NaN
#
# [138 rows x 4 columns]

# %%
merged_df3 = cleaned_country_df.merge(tsunami_df, on="Country_Name", how="outer", indicator=True)
merged_df3
# Out:
#     Country_Abbreviation               Country_Name  Country_ID  \
# 0                    DZA                    Algeria          12
# 1                    EGY                      Egypt         818
# 2                    LBY                      Libya         434
# 3                    MAR                    Morocco         504
# 4                    SDN                      Sudan         729
# ..                   ...                        ...         ...
# 342                  WSM                      Samoa         882
# 343                  TKL                    Tokelau         772
# 344                  TON                      Tonga         776
# 345                  TUV                     Tuvalu         798
# 346                  WLF  Wallis and Futuna Islands         876
#
#     Developed_Or_Developing  Year Cause Total_Deaths     _merge
# 0                Developing   NaN   NaN          NaN  left_only
# 1                Developing   NaN   NaN          NaN  left_only
# 2                Developing   NaN   NaN          NaN  left_only
# 3                Developing   NaN   NaN          NaN  left_only
# 4                Developing   NaN   NaN          NaN  left_only
# ..                      ...   ...   ...          ...        ...
# 342              Developing   NaN   NaN          NaN  left_only
# 343              Developing   NaN   NaN          NaN  left_only
# 344              Developing   NaN   NaN          NaN  left_only
# 345              Developing   NaN   NaN          NaN  left_only
# 346              Developing   NaN   NaN          NaN  left_only
#
# [347 rows x 8 columns]

# %%
merged_df3[merged_df3["_merge"] == "right_only"]
# Out:
# Empty DataFrame
# Columns: [Country_Abbreviation, Country_Name, Country_ID, Developed_Or_Developing, Year, Cause, Total_Deaths, _merge]
# Index: []

# %%
#
