# %%
# Dependencies
import pandas as pd
import csv, os

# %%
# File paths
data_path_1 = "Resources/WH_2015.csv"
data_path_2 = "Resources/WH_2016.csv"
data_path_3 = "Resources/WH_2017.csv"
data_path_4 = "Resources/WH_2018.csv"

# %%
# Read CSV
wh_2015_db = pd.read_csv(data_path_1)
wh_2016_db = pd.read_csv(data_path_2)
wh_2017_db = pd.read_csv(data_path_3)
wh_2018_db = pd.read_csv(data_path_4)

# %%
# Drop unwanted columns and merge
wh_2015_v1 = wh_2015_db.loc[:, ["Country",
                                "Happiness Rank",
                                "Happiness Score"]]

wh_2016_v1 = wh_2016_db.loc[:, ["Country",
                                "Happiness Rank",
                                "Happiness Score"]]

combined_df =  pd.merge(wh_2015_v1,wh_2016_v1, on = ["Country"], how = "outer")

# %%
# Rename columns
combined_df = combined_df.rename(columns = {"Happiness Rank_x": "Rank_2015",
                                            "Happiness Score_x": "Score_2015",
                                            "Happiness Rank_y": "Rank_2016",
                                            "Happiness Score_y":"Score_2016"})

combined_df.head()
# Out:
#        Country  Rank_2015  Score_2015  Rank_2016  Score_2016
# 0  Switzerland        1.0       7.587        2.0       7.509
# 1      Iceland        2.0       7.561        3.0       7.501
# 2      Denmark        3.0       7.527        1.0       7.526
# 3       Norway        4.0       7.522        4.0       7.498
# 4       Canada        5.0       7.427        6.0       7.404

# %%
# Drop unwanted columns and merge
wh_2017_v1 = wh_2017_db.loc[:, ["Country",
                                "Happiness.Rank",
                                "Happiness.Score"]]

combined_df =  pd.merge(combined_df,wh_2017_v1, on = ["Country"], how = "outer")
combined_df
# Out:
#                       Country  Rank_2015  Score_2015  Rank_2016  Score_2016  \
# 0                 Switzerland        1.0       7.587        2.0       7.509
# 1                     Iceland        2.0       7.561        3.0       7.501
# 2                     Denmark        3.0       7.527        1.0       7.526
# 3                      Norway        4.0       7.522        4.0       7.498
# 4                      Canada        5.0       7.427        6.0       7.404
# ..                        ...        ...         ...        ...         ...
# 161         Somaliland Region        NaN         NaN       97.0       5.057
# 162                   Namibia        NaN         NaN      113.0       4.574
# 163               South Sudan        NaN         NaN      143.0       3.832
# 164  Taiwan Province of China        NaN         NaN        NaN         NaN
# 165   Hong Kong S.A.R., China        NaN         NaN        NaN         NaN
#
#      Happiness.Rank  Happiness.Score
# 0               4.0            7.494
# 1               3.0            7.504
# 2               2.0            7.522
# 3               1.0            7.537
# 4               7.0            7.316
# ..              ...              ...
# 161             NaN              NaN
# 162           111.0            4.574
# 163           147.0            3.591
# 164            33.0            6.422
# 165            71.0            5.472
#
# [166 rows x 7 columns]

# %%
# Rename columns
combined_df = combined_df.rename(columns = {"Happiness.Rank": "Rank_2017",
                                            "Happiness.Score": "Score_2017"})

combined_df.head()
# Out:
#        Country  Rank_2015  Score_2015  Rank_2016  Score_2016  Rank_2017  \
# 0  Switzerland        1.0       7.587        2.0       7.509        4.0
# 1      Iceland        2.0       7.561        3.0       7.501        3.0
# 2      Denmark        3.0       7.527        1.0       7.526        2.0
# 3       Norway        4.0       7.522        4.0       7.498        1.0
# 4       Canada        5.0       7.427        6.0       7.404        7.0
#
#    Score_2017
# 0       7.494
# 1       7.504
# 2       7.522
# 3       7.537
# 4       7.316

# %%
# Drop unwanted columns, rename and merge
wh_2018_v1 = wh_2018_db.loc[:, ["Country or region",
                                "Overall rank",
                                "Score"]]

wh_2018_v1 = wh_2018_v1.rename(columns = {"Country or region": "Country",
                                          "Overall rank": "Rank_2018",
                                          "Score": "Score_2018"})

combined_df =  pd.merge(combined_df,wh_2018_v1, on = ["Country"], how = "outer")

# %% [markdown]
# # Drop unwanted columns, rename and merge
# wh_2019_v1 = wh_2019_db.loc[:, ["Country or region",
#                                 "Overall rank",
#                                 "Score"]]
#
# wh_2019_v1 = wh_2019_v1.rename(columns = {"Country or region": "Country",
#                                           "Overall rank": "Rank_2019",
#                                           "Score": "Score_2019"})
#
# combined_df =  pd.merge(combined_df,wh_2019_v1, on = ["Country"], how = "outer")
# combined_df

# %%
# Convert Country column name 
combined_df = combined_df.rename(columns = {"Country" : "Country_Name"})
combined_df
# Out:
#                  Country_Name  Rank_2015  Score_2015  Rank_2016  Score_2016  \
# 0                 Switzerland        1.0       7.587        2.0       7.509
# 1                     Iceland        2.0       7.561        3.0       7.501
# 2                     Denmark        3.0       7.527        1.0       7.526
# 3                      Norway        4.0       7.522        4.0       7.498
# 4                      Canada        5.0       7.427        6.0       7.404
# ..                        ...        ...         ...        ...         ...
# 163               South Sudan        NaN         NaN      143.0       3.832
# 164  Taiwan Province of China        NaN         NaN        NaN         NaN
# 165   Hong Kong S.A.R., China        NaN         NaN        NaN         NaN
# 166         Trinidad & Tobago        NaN         NaN        NaN         NaN
# 167           Northern Cyprus        NaN         NaN        NaN         NaN
#
#      Rank_2017  Score_2017  Rank_2018  Score_2018
# 0          4.0       7.494        5.0       7.487
# 1          3.0       7.504        4.0       7.495
# 2          2.0       7.522        3.0       7.555
# 3          1.0       7.537        2.0       7.594
# 4          7.0       7.316        7.0       7.328
# ..         ...         ...        ...         ...
# 163      147.0       3.591      154.0       3.254
# 164       33.0       6.422        NaN         NaN
# 165       71.0       5.472        NaN         NaN
# 166        NaN         NaN       38.0       6.192
# 167        NaN         NaN       58.0       5.835
#
# [168 rows x 9 columns]

# %%
# Save to CSV
combined_df.to_csv("Resources/cleaned_WH_data.CSV", index = False)

# %%
country_df = pd.DataFrame(combined_df["Country_Name"])
country_df
# Out:
#                  Country_Name
# 0                 Switzerland
# 1                     Iceland
# 2                     Denmark
# 3                      Norway
# 4                      Canada
# ..                        ...
# 163               South Sudan
# 164  Taiwan Province of China
# 165   Hong Kong S.A.R., China
# 166         Trinidad & Tobago
# 167           Northern Cyprus
#
# [168 rows x 1 columns]

# %%
volcano_path = "Resources/cleaned_volcano_data.CSV"
volcano_df= pd.read_csv(volcano_path)
volcano_df
# Out:
#     Year              Country_Name  Elevation  Total_Deaths  \
# 0   2015                 Indonesia       2460           NaN
# 1   2015                     Chile       2003           NaN
# 2   2015                 Indonesia       1784           NaN
# 3   2015          Papua New Guinea       1807           NaN
# 4   2015                 Indonesia       2460           1.0
# 5   2015               New Zealand       1111           1.0
# 6   2016                 Indonesia       2460           1.0
# 7   2016                 Indonesia       2460           7.0
# 8   2016  United States of America       2805           1.0
# 9   2016                 Indonesia       3726           NaN
# 10  2016                     Japan       1592           NaN
# 11  2017                     Italy       3350           NaN
# 12  2017                 Indonesia       2460           NaN
# 13  2017                 Guatemala       3763           NaN
# 14  2017                 Indonesia       2565           8.0
# 15  2017                     Italy        458           3.0
# 16  2017                   Vanuatu       1496           NaN
# 17  2017                 Indonesia       2947           8.0
# 18  2017                 Indonesia       2460           NaN
# 19  2018          Papua New Guinea        365           NaN
# 20  2018               Philippines       2462           NaN
# 21  2018                     Japan       2176           1.0
# 22  2018  United States of America       1222           1.0
# 23  2018          Papua New Guinea        365           NaN
# 24  2018                 Indonesia       2799           NaN
# 25  2018  United States of America       1222           NaN
# 26  2018                   Vanuatu       1496           4.0
#
#     Total_Missing_Persons  Total_Injuries
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             2.0
# 4                     NaN             NaN
# 5                     NaN             NaN
# 6                     NaN             4.0
# 7                     NaN             3.0
# 8                     NaN             NaN
# 9                    44.0             NaN
# 10                    NaN             NaN
# 11                    NaN            10.0
# 12                    NaN             NaN
# 13                    NaN             NaN
# 14                    NaN            11.0
# 15                    NaN             NaN
# 16                    NaN             NaN
# 17                    NaN             8.0
# 18                    NaN             NaN
# 19                    NaN             NaN
# 20                    NaN          1972.0
# 21                    NaN            11.0
# 22                    NaN             3.0
# 23                    NaN             NaN
# 24                    NaN            30.0
# 25                    NaN             NaN
# 26                    NaN             NaN

# %%
# Test for country column consistency
merged_df = country_df.merge(volcano_df, on="Country_Name", how="outer", indicator=True)
merged_df
# Out:
#                  Country_Name    Year  Elevation  Total_Deaths  \
# 0                 Switzerland     NaN        NaN           NaN
# 1                     Iceland     NaN        NaN           NaN
# 2                     Denmark     NaN        NaN           NaN
# 3                      Norway     NaN        NaN           NaN
# 4                      Canada     NaN        NaN           NaN
# ..                        ...     ...        ...           ...
# 183  United States of America  2016.0     2805.0           1.0
# 184  United States of America  2018.0     1222.0           1.0
# 185  United States of America  2018.0     1222.0           NaN
# 186                   Vanuatu  2017.0     1496.0           NaN
# 187                   Vanuatu  2018.0     1496.0           4.0
#
#      Total_Missing_Persons  Total_Injuries      _merge
# 0                      NaN             NaN   left_only
# 1                      NaN             NaN   left_only
# 2                      NaN             NaN   left_only
# 3                      NaN             NaN   left_only
# 4                      NaN             NaN   left_only
# ..                     ...             ...         ...
# 183                    NaN             NaN  right_only
# 184                    NaN             3.0  right_only
# 185                    NaN             NaN  right_only
# 186                    NaN             NaN  right_only
# 187                    NaN             NaN  right_only
#
# [188 rows x 7 columns]

# %%
merged_df[merged_df["_merge"] == "right_only"]
# Out:
#                  Country_Name    Year  Elevation  Total_Deaths  \
# 180          Papua New Guinea  2015.0     1807.0           NaN
# 181          Papua New Guinea  2018.0      365.0           NaN
# 182          Papua New Guinea  2018.0      365.0           NaN
# 183  United States of America  2016.0     2805.0           1.0
# 184  United States of America  2018.0     1222.0           1.0
# 185  United States of America  2018.0     1222.0           NaN
# 186                   Vanuatu  2017.0     1496.0           NaN
# 187                   Vanuatu  2018.0     1496.0           4.0
#
#      Total_Missing_Persons  Total_Injuries      _merge
# 180                    NaN             2.0  right_only
# 181                    NaN             NaN  right_only
# 182                    NaN             NaN  right_only
# 183                    NaN             NaN  right_only
# 184                    NaN             3.0  right_only
# 185                    NaN             NaN  right_only
# 186                    NaN             NaN  right_only
# 187                    NaN             NaN  right_only

# %%
country_path = "Resources/UNSD — Methodology.CSV"
country_df = pd.read_csv(country_path, error_bad_lines=False)
country_df
# Out:
# C:\Users\franc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 67: expected 16 fields, saw 17\nSkipping line 126: expected 16 fields, saw 17\nSkipping line 127: expected 16 fields, saw 17\n'
#      Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0              1       World          2.0      Africa             15.0
# 1              1       World          2.0      Africa             15.0
# 2              1       World          2.0      Africa             15.0
# 3              1       World          2.0      Africa             15.0
# 4              1       World          2.0      Africa             15.0
# ..           ...         ...          ...         ...              ...
# 241            1       World          9.0     Oceania             61.0
# 242            1       World          9.0     Oceania             61.0
# 243            1       World          9.0     Oceania             61.0
# 244            1       World          9.0     Oceania             61.0
# 245            1       World          9.0     Oceania             61.0
#
#      Sub-region Name  Intermediate Region Code Intermediate Region Name  \
# 0    Northern Africa                       NaN                      NaN
# 1    Northern Africa                       NaN                      NaN
# 2    Northern Africa                       NaN                      NaN
# 3    Northern Africa                       NaN                      NaN
# 4    Northern Africa                       NaN                      NaN
# ..               ...                       ...                      ...
# 241        Polynesia                       NaN                      NaN
# 242        Polynesia                       NaN                      NaN
# 243        Polynesia                       NaN                      NaN
# 244        Polynesia                       NaN                      NaN
# 245        Polynesia                       NaN                      NaN
#
#                Country or Area  M49 Code ISO-alpha2 Code ISO-alpha3 Code  \
# 0                      Algeria        12              DZ             DZA
# 1                        Egypt       818              EG             EGY
# 2                        Libya       434              LY             LBY
# 3                      Morocco       504              MA             MAR
# 4                        Sudan       729              SD             SDN
# ..                         ...       ...             ...             ...
# 241                      Samoa       882              WS             WSM
# 242                    Tokelau       772              TK             TKL
# 243                      Tonga       776              TO             TON
# 244                     Tuvalu       798              TV             TUV
# 245  Wallis and Futuna Islands       876              WF             WLF
#
#     Least Developed Countries (LDC) Land Locked Developing Countries (LLDC)  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                                 x                                     NaN
# ..                              ...                                     ...
# 241                             NaN                                     NaN
# 242                             NaN                                     NaN
# 243                             NaN                                     NaN
# 244                               x                                     NaN
# 245                             NaN                                     NaN
#
#     Small Island Developing States (SIDS) Developed / Developing Countries
# 0                                     NaN                       Developing
# 1                                     NaN                       Developing
# 2                                     NaN                       Developing
# 3                                     NaN                       Developing
# 4                                     NaN                       Developing
# ..                                    ...                              ...
# 241                                     x                       Developing
# 242                                   NaN                       Developing
# 243                                     x                       Developing
# 244                                     x                       Developing
# 245                                   NaN                       Developing
#
# [246 rows x 16 columns]

# %%
# Dropping unwanted columns
cleaned_country_df = pd.DataFrame(country_df, columns = {"Country or Area", "M49 Code", "ISO-alpha3 Code", "Developed / Developing Countries"})
cleaned_country_df
# Out:
#                Country or Area  M49 Code Developed / Developing Countries  \
# 0                      Algeria        12                       Developing
# 1                        Egypt       818                       Developing
# 2                        Libya       434                       Developing
# 3                      Morocco       504                       Developing
# 4                        Sudan       729                       Developing
# ..                         ...       ...                              ...
# 241                      Samoa       882                       Developing
# 242                    Tokelau       772                       Developing
# 243                      Tonga       776                       Developing
# 244                     Tuvalu       798                       Developing
# 245  Wallis and Futuna Islands       876                       Developing
#
#     ISO-alpha3 Code
# 0               DZA
# 1               EGY
# 2               LBY
# 3               MAR
# 4               SDN
# ..              ...
# 241             WSM
# 242             TKL
# 243             TON
# 244             TUV
# 245             WLF
#
# [246 rows x 4 columns]

# %%
# Checking for duplicates
cleaned_country_df.drop_duplicates(subset=['Country or Area'])
cleaned_country_df
# Out:
#                Country or Area  M49 Code Developed / Developing Countries  \
# 0                      Algeria        12                       Developing
# 1                        Egypt       818                       Developing
# 2                        Libya       434                       Developing
# 3                      Morocco       504                       Developing
# 4                        Sudan       729                       Developing
# ..                         ...       ...                              ...
# 241                      Samoa       882                       Developing
# 242                    Tokelau       772                       Developing
# 243                      Tonga       776                       Developing
# 244                     Tuvalu       798                       Developing
# 245  Wallis and Futuna Islands       876                       Developing
#
#     ISO-alpha3 Code
# 0               DZA
# 1               EGY
# 2               LBY
# 3               MAR
# 4               SDN
# ..              ...
# 241             WSM
# 242             TKL
# 243             TON
# 244             TUV
# 245             WLF
#
# [246 rows x 4 columns]

# %%
cleaned_country_df = cleaned_country_df.rename(columns = {"Country or Area": "Country_Name",
                                                          "M49 Code":"Country_ID",
                                                          "ISO-alpha3 Code": "Country_Abbreviation",
                                                         "Developed / Developing Countries": "Developed_Or_Developing"})
cleaned_country_df
# Out:
#                   Country_Name  Country_ID Developed_Or_Developing  \
# 0                      Algeria          12              Developing
# 1                        Egypt         818              Developing
# 2                        Libya         434              Developing
# 3                      Morocco         504              Developing
# 4                        Sudan         729              Developing
# ..                         ...         ...                     ...
# 241                      Samoa         882              Developing
# 242                    Tokelau         772              Developing
# 243                      Tonga         776              Developing
# 244                     Tuvalu         798              Developing
# 245  Wallis and Futuna Islands         876              Developing
#
#     Country_Abbreviation
# 0                    DZA
# 1                    EGY
# 2                    LBY
# 3                    MAR
# 4                    SDN
# ..                   ...
# 241                  WSM
# 242                  TKL
# 243                  TON
# 244                  TUV
# 245                  WLF
#
# [246 rows x 4 columns]

# %%
# Save to CSV
cleaned_country_df.to_csv("Resources/cleaned_country_data.CSV", index = False)

# %%
# Test for country column consistency
merged_df = cleaned_country_df.merge(volcano_df, on="Country_Name", how="outer", indicator=True)
merged_df
# Out:
#                   Country_Name  Country_ID Developed_Or_Developing  \
# 0                      Algeria          12              Developing
# 1                        Egypt         818              Developing
# 2                        Libya         434              Developing
# 3                      Morocco         504              Developing
# 4                        Sudan         729              Developing
# ..                         ...         ...                     ...
# 258                      Samoa         882              Developing
# 259                    Tokelau         772              Developing
# 260                      Tonga         776              Developing
# 261                     Tuvalu         798              Developing
# 262  Wallis and Futuna Islands         876              Developing
#
#     Country_Abbreviation  Year  Elevation  Total_Deaths  \
# 0                    DZA   NaN        NaN           NaN
# 1                    EGY   NaN        NaN           NaN
# 2                    LBY   NaN        NaN           NaN
# 3                    MAR   NaN        NaN           NaN
# 4                    SDN   NaN        NaN           NaN
# ..                   ...   ...        ...           ...
# 258                  WSM   NaN        NaN           NaN
# 259                  TKL   NaN        NaN           NaN
# 260                  TON   NaN        NaN           NaN
# 261                  TUV   NaN        NaN           NaN
# 262                  WLF   NaN        NaN           NaN
#
#      Total_Missing_Persons  Total_Injuries     _merge
# 0                      NaN             NaN  left_only
# 1                      NaN             NaN  left_only
# 2                      NaN             NaN  left_only
# 3                      NaN             NaN  left_only
# 4                      NaN             NaN  left_only
# ..                     ...             ...        ...
# 258                    NaN             NaN  left_only
# 259                    NaN             NaN  left_only
# 260                    NaN             NaN  left_only
# 261                    NaN             NaN  left_only
# 262                    NaN             NaN  left_only
#
# [263 rows x 10 columns]

# %%
merged_df[merged_df["_merge"] == "right_only"]
# Out:
# Empty DataFrame
# Columns: [Country_Name, Country_ID, Developed_Or_Developing, Country_Abbreviation, Year, Elevation, Total_Deaths, Total_Missing_Persons, Total_Injuries, _merge]
# Index: []

# %%
earthquake_path = "Resources/cleaned_worldwide_earthquake_data.CSV"
earthquake_df= pd.read_csv(earthquake_path)
earthquake_df
# Out:
#      Year  Magnitude            Country_Name  Total_Deaths  \
# 0    2015        NaN                   China           NaN
# 1    2015        6.7                   Japan           NaN
# 2    2015        6.4                 Vanuatu           NaN
# 3    2015        NaN                   China           NaN
# 4    2015        NaN  Bosnia and Herzegovina           4.0
# ..    ...        ...                     ...           ...
# 224  2018        7.5           New Caledonia           NaN
# 225  2018        5.6                 Vanuatu           NaN
# 226  2018        5.4                   China           NaN
# 227  2018        5.5              Mozambique           NaN
# 228  2018        NaN                   Italy           NaN
#
#      Total_Missing_Persons  Total_Injuries
# 0                      NaN            11.0
# 1                      NaN             NaN
# 2                      NaN             NaN
# 3                      NaN             NaN
# 4                      NaN             1.0
# ..                     ...             ...
# 224                    NaN             NaN
# 225                    NaN             NaN
# 226                    NaN            17.0
# 227                    NaN            10.0
# 228                    NaN            28.0
#
# [229 rows x 6 columns]

# %%
merged_df2 = cleaned_country_df.merge(earthquake_df, on="Country_Name", how="outer", indicator=True)
merged_df2
# Out:
#                   Country_Name  Country_ID Developed_Or_Developing  \
# 0                      Algeria          12              Developing
# 1                        Egypt         818              Developing
# 2                        Libya         434              Developing
# 3                      Morocco         504              Developing
# 4                        Sudan         729              Developing
# ..                         ...         ...                     ...
# 413                      Samoa         882              Developing
# 414                    Tokelau         772              Developing
# 415                      Tonga         776              Developing
# 416                     Tuvalu         798              Developing
# 417  Wallis and Futuna Islands         876              Developing
#
#     Country_Abbreviation    Year  Magnitude  Total_Deaths  \
# 0                    DZA  2016.0        5.4           NaN
# 1                    EGY     NaN        NaN           NaN
# 2                    LBY     NaN        NaN           NaN
# 3                    MAR  2016.0        6.3           1.0
# 4                    SDN     NaN        NaN           NaN
# ..                   ...     ...        ...           ...
# 413                  WSM     NaN        NaN           NaN
# 414                  TKL     NaN        NaN           NaN
# 415                  TON     NaN        NaN           NaN
# 416                  TUV     NaN        NaN           NaN
# 417                  WLF     NaN        NaN           NaN
#
#      Total_Missing_Persons  Total_Injuries     _merge
# 0                      NaN            28.0       both
# 1                      NaN             NaN  left_only
# 2                      NaN             NaN  left_only
# 3                      NaN            26.0       both
# 4                      NaN             NaN  left_only
# ..                     ...             ...        ...
# 413                    NaN             NaN  left_only
# 414                    NaN             NaN  left_only
# 415                    NaN             NaN  left_only
# 416                    NaN             NaN  left_only
# 417                    NaN             NaN  left_only
#
# [418 rows x 10 columns]

# %%
merged_df2[merged_df2["_merge"] == "right_only"]
# Out:
# Empty DataFrame
# Columns: [Country_Name, Country_ID, Developed_Or_Developing, Country_Abbreviation, Year, Magnitude, Total_Deaths, Total_Missing_Persons, Total_Injuries, _merge]
# Index: []

# %%
tsunami_path = "Resources/cleaned_tsunami_data.CSV"
tsunami_df= pd.read_csv(tsunami_path)
tsunami_df
# Out:
#     Year        Country_Name       Cause Total_Deaths
# 0   2015               Japan  Earthquake          NaN
# 1   2015    Papua New Guinea  Earthquake          NaN
# 2   2015             Vanuatu  Earthquake          NaN
# 3   2015               Japan  Earthquake          NaN
# 4   2015    Papua New Guinea  Earthquake          NaN
# ..   ...                 ...         ...          ...
# 58  2017       New Caledonia  Earthquake          NaN
# 59  2017       New Caledonia  Earthquake          NaN
# 60  2018       New Caledonia  Earthquake          NaN
# 61  2018  Russian Federation   Landslide          NaN
# 62  2016               Japan  Earthquake          NaN
#
# [63 rows x 4 columns]

# %%
merged_df3 = cleaned_country_df.merge(tsunami_df, on="Country_Name", how="outer", indicator=True)
merged_df3
# Out:
#                   Country_Name  Country_ID Developed_Or_Developing  \
# 0                      Algeria          12              Developing
# 1                        Egypt         818              Developing
# 2                        Libya         434              Developing
# 3                      Morocco         504              Developing
# 4                        Sudan         729              Developing
# ..                         ...         ...                     ...
# 278                      Samoa         882              Developing
# 279                    Tokelau         772              Developing
# 280                      Tonga         776              Developing
# 281                     Tuvalu         798              Developing
# 282  Wallis and Futuna Islands         876              Developing
#
#     Country_Abbreviation  Year Cause Total_Deaths     _merge
# 0                    DZA   NaN   NaN          NaN  left_only
# 1                    EGY   NaN   NaN          NaN  left_only
# 2                    LBY   NaN   NaN          NaN  left_only
# 3                    MAR   NaN   NaN          NaN  left_only
# 4                    SDN   NaN   NaN          NaN  left_only
# ..                   ...   ...   ...          ...        ...
# 278                  WSM   NaN   NaN          NaN  left_only
# 279                  TKL   NaN   NaN          NaN  left_only
# 280                  TON   NaN   NaN          NaN  left_only
# 281                  TUV   NaN   NaN          NaN  left_only
# 282                  WLF   NaN   NaN          NaN  left_only
#
# [283 rows x 8 columns]

# %%
merged_df3[merged_df3["_merge"] == "right_only"]
# Out:
# Empty DataFrame
# Columns: [Country_Name, Country_ID, Developed_Or_Developing, Country_Abbreviation, Year, Cause, Total_Deaths, _merge]
# Index: []

# %%
#
